# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_json("results/result.json")
loss = data["loss"]
plt.plot(loss)
plt.xlabel("Epoch", loc="center", fontdict={"size": 16})
plt.ylabel("Loss", loc="center", fontdict={"size": 16})
plt.title("XOR with MSE and Sigmoid")
plt.grid(True, which="both")
plt.show()
# loss

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_json("results/result.json")
loss = data["loss"]
plt.plot(loss)
plt.xlabel("Epoch", loc="center", fontdict={"size": 16})
plt.ylabel("Loss", loc="center", fontdict={"size": 16})
plt.title("XOR with MSE and RelU")
plt.grid(True, which="both")
plt.show()
